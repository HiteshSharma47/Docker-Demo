# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("CaseStudy").getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/06/17 03:35:41 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/06/17 03:35:59 WARN GarbageCollectionMetrics: To enable non-built-in garbage collector(s) List(G1 Concurrent GC), users should configure it(them) to spark.eventLog.gcMetrics.youngGenerationGarbageCollectors or spark.eventLog.gcMetrics.oldGenerationGarbageCollectors

# %%
df1 = spark.read.csv("data/customers.csv", header=True)
df2 = spark.read.csv("data/order_items.csv", header=True)
df3 = spark.read.csv("data/orders.csv", header=True)
df4 = spark.read.csv("data/products.csv", header=True)
df5 = spark.read.csv("data/returns.csv", header=True)

# %%
# 1). Calculate the total number of customers, products, orders, and returned orders.

# %%
print("Customers Data:", df1.count())
print("Order Items Data:", df2.count())
print("Orders Data:", df3.count())
print("Products Data:", df4.count())
print("Returns Data:", df5.count())
# Out:
# Customers Data: 100000
# Order Items Data: 3000000
# Orders Data: 1000000
# Products Data: 50000
# Returns Data: 100000

# %%
# 2). Find the total sales amount generated by each product category
